# %% [markdown]
# \begin{equation}
# \boldsymbol{\sigma}=
# \begin{bmatrix} \sigma_{11} & \sigma_{21} & \sigma_{31} \\
#                 \sigma_{12} & \sigma_{22} & \sigma_{32} \\
#                 \sigma_{13} & \sigma_{23}  & \sigma_{33}
# \end{bmatrix} = \begin{bmatrix} 20 & 80 & 2 \\
# 10 & 20 & 0 \\
# 0 & 30 & 20
# \end{bmatrix}
# \end{equation}
#
# \begin{equation}
# \boldsymbol{\sigma}=
# \begin{bmatrix} \sigma_{11} & \sigma_{21} & \sigma_{31} \\
#                 \sigma_{12} & \sigma_{22} & \sigma_{32} \\
#                 \sigma_{13} & \sigma_{23}  & \sigma_{33}
# \end{bmatrix} = \begin{bmatrix} 60 & 70 & 0 \\
# 10 & 0 & 0 \\
# 0 & 40 & 0
# \end{bmatrix}
# \end{equation}
#
# \begin{equation}
# \boldsymbol{\sigma}=
# \begin{bmatrix} \sigma_{11} & \sigma_{21} & \sigma_{31} \\
#                 \sigma_{12} & \sigma_{22} & \sigma_{32} \\
#                 \sigma_{13} & \sigma_{23}  & \sigma_{33}
# \end{bmatrix} = \begin{bmatrix} 40 & 80 & 5 \\
# 10 & 0 & 0 \\
# 0 & 50 & 20
# \end{bmatrix}
# \end{equation}
